# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wind_data = pd.read_csv('../cleaned_datasets/wind_data.csv')
wind_data = wind_data[wind_data.columns[1:]]
wind_data.head()
# Out:
#    plant_id         plant                              op  op_id plant_state  \
# 0         1    Sand Point  TDX Sand Point Generating, LLC  63560          AK
# 1        90   Snake River      Nome Joint Utility Systems  13642          AK
# 2       508   Lamar Plant            City of Lamar - (CO)  10633          CO
# 3       692  Medicine Bow            SRIV Partnership LLC  62042          WY
# 4       944       Geneseo          City of Geneseo - (IL)   7095          IL
#
#   region rpm  fuel_usage  net_gen
# 0   PACN  WT        3045    347.0
# 1   PACN  WT       20906   2383.0
# 2    MTN  WT      116085  13232.0
# 3    MTN  WT      141429  16121.0
# 4    ENC  WT       51368   5855.0

# %%
def plant_type(row):
    if row == 'WT':
        output = 'Onshore'
    if row == 'WS':
        output = 'Offshore'
    return output

# %%
wind_data['rpm'] = wind_data['rpm'].apply(plant_type)

# %%
wind_data.groupby('plant_state')['op_id'].count().sort_values(ascending=False).head(5)
# Out:
# plant_state
# TX    190
# MN    129
# CA    114
# IA    112
# OK     57
# Name: op_id, dtype: int64

# %%
operator_counts = pd.concat([wind_data.groupby('plant_state')['op_id'].count().sort_values(ascending=False).head(), wind_data.groupby('plant_state')['op_id'].count().sort_values(ascending=False).tail()])

# %%
op_counts_bar = operator_counts.plot(kind='bar', title='The States w/ the Most & Least Operators', color='orange', xlabel='States', rot=0)
for p in op_counts_bar.patches:
    op_counts_bar.annotate(str(p.get_height()), (p.get_x() + 0.05, p.get_height() + 3))
op_counts_bar.figure.savefig('../charts/op_counts_bar');

# %%
operator_regions = pd.concat([wind_data.groupby('region')['op_id'].count().sort_values(ascending=False).head(), wind_data.groupby('region')['op_id'].count().sort_values(ascending=False).tail()])

# %%
op_regions_bar = operator_regions.plot(kind='bar', title='The Regions w/ the Most & Least Operators', color='orange', xlabel='Regions', rot=0)
for p in op_regions_bar.patches:
    op_regions_bar.annotate(str(p.get_height()), (p.get_x() + 0.05, p.get_height() + 3))
op_regions_bar.figure.savefig('../charts/op_regions_bar');

# %%
operator_gen = pd.concat([wind_data.groupby(['plant_state'])['net_gen'].mean().sort_values(ascending=False).head(), wind_data.groupby('plant_state')['net_gen'].mean().sort_values(ascending=False).tail()])

# %%
op_gen_bar = operator_gen.plot(kind='bar', title='The States w/ the Highest & Least Average Annual Generation', color='orange', xlabel='States', rot=0)
op_gen_bar.figure.savefig('../charts/op_gen_bar');

# %%
rpm_gen = pd.concat([wind_data.groupby(['rpm'])['net_gen'].mean().sort_values(ascending=False).head(1), wind_data.groupby('rpm')['net_gen'].mean().sort_values(ascending=False).tail(1)])

# %%
rpm_gen_bar = rpm_gen.plot(kind='bar', title='Onshore VS Offshore - Average Annual Generation', color='green', xlabel='Plant Type', rot=0)
rpm_gen_bar.figure.savefig('../charts/rpm_gen_bar');

# %%
manu_data = pd.read_csv('../cleaned_datasets/manu_data.csv')
manu_data = manu_data[manu_data.columns[1:]]
manu_data
# Out:
#        case_id                  t_manu     t_model   t_cap  t_hh   t_rd  \
# 0      3063272                  Nordex  AW125/3000  3000.0  87.5  125.0
# 1      3053390                  Nordex  AW125/3000  3000.0  87.5  125.0
# 2      3063269                  Nordex  AW125/3000  3000.0  87.5  125.0
# 3      3049500                  Nordex  AW125/3000  3000.0  87.5  125.0
# 4      3049502                  Nordex  AW125/3000  3000.0  87.5  125.0
# ...        ...                     ...         ...     ...   ...    ...
# 64476  3057399                 GE Wind   GE1.7-100  1700.0  80.0  100.0
# 64477  3057398                 GE Wind   GE1.7-100  1700.0  80.0  100.0
# 64478  3052682  Northern Power Systems     NPS-100   100.0  37.0   21.0
# 64479  3003325                Seaforth    AOC15/65    65.0  30.5   15.0
# 64480  3001855                Seaforth    AOC15/65    65.0  30.5   15.0
#
#           t_rsa  t_ttlh  t_conf_atr    size
# 0      12271.85   150.0           3   large
# 1      12271.85   150.0           3   large
# 2      12271.85   150.0           3   large
# 3      12271.85   150.0           3   large
# 4      12271.85   150.0           3   large
# ...         ...     ...         ...     ...
# 64476   7853.98   130.1           3  medium
# 64477   7853.98   130.1           3  medium
# 64478    346.36    47.5           3   small
# 64479    176.71    38.0           1   small
# 64480    176.71    38.0           1   small
#
# [64481 rows x 10 columns]

# %%
import statistics as stat
median_height = stat.median(manu_data['t_rd'])
std_height = stat.stdev(manu_data['t_rd'])
def height_category(row):
    if row > median_height + std_height:
        outcome = 'large'
    elif row >= median_height - std_height:
        outcome = 'medium'
    else:
        outcome = 'small'
    return outcome

# %%
manu_data['size'] = manu_data['t_rd'].apply(height_category)

# %%
manu_data['size'].value_counts()
# Out:
# medium    43347
# small     13258
# large      7876
# Name: size, dtype: int64

# %%
turbine_size_bar = manu_data['size'].value_counts().plot(kind='bar', title='Turbine Sizes Across the US', color='green', xlabel=None, rot=0)
turbine_size_bar.figure.savefig('../charts/turbine_size_bar');

# %%
wind_data[wind_data['rpm'] == 'Offshore']
# Out:
#      plant_id                   plant                               op  op_id  \
# 728     58035  Block Island Wind Farm  Deepwater Wind Block Island LLC  57406
#
#     plant_state region       rpm  fuel_usage   net_gen
# 728          RI    NEW  Offshore     1054767  120229.0

# %%
manu_data.to_csv('../cleaned_datasets/manu_data.csv')

# %%
wind_turbines = pd.read_csv('../cleaned_datasets/wind_turbines.csv')
wind_turbines = wind_turbines[wind_turbines.columns[1:]]
wind_turbines
# Out:
#        case_id t_state        t_county                   p_name  p_year  \
# 0      3072661      CA     Kern County                 251 Wind  1987.0
# 1      3072695      CA     Kern County                 251 Wind  1987.0
# 2      3072704      CA     Kern County                 251 Wind  1987.0
# 3      3063272      IA    Story County  30 MW Iowa DG Portfolio  2017.0
# 4      3053390      IA    Boone County  30 MW Iowa DG Portfolio  2017.0
# ...        ...     ...             ...                      ...     ...
# 70803  3053232      NY  Wyoming County   unknown Wyoming County  2016.0
# 70804  3101958      TX    Young County     unknown Young County     NaN
# 70805  3040944      TX    Young County   unknown Young County 1  2011.0
# 70806  3055918      CO     Yuma County      unknown Yuma County  2016.0
# 70807  3055917      CO     Yuma County      unknown Yuma County  2016.0
#
#        p_tnum  p_cap  retrofit       xlong       ylat
# 0         194  18.43         0 -118.363762  35.077908
# 1         194  18.43         0 -118.364410  35.077435
# 2         194  18.43         0 -118.364197  35.077644
# 3          10  30.00         0  -93.430367  42.028233
# 4          10  30.00         0  -93.700424  41.977608
# ...       ...    ...       ...         ...        ...
# 70803       1    NaN         0  -78.187935  42.740818
# 70804       1    NaN         0  -98.907600  33.149414
# 70805       1    NaN         0  -98.551094  33.093292
# 70806       2    NaN         0 -102.716949  40.037548
# 70807       2    NaN         0 -102.717171  40.035072
#
# [70808 rows x 10 columns]

# %%
turbine_sizes = pd.merge(left=wind_turbines, right=manu_data, how='left', on='case_id')
turbine_sizes.dropna(inplace=True)
turbine_sizes
# Out:
#        case_id t_state                  t_county  \
# 3      3063272      IA              Story County
# 4      3053390      IA              Boone County
# 5      3063269      IA              Story County
# 6      3049500      IA              Story County
# 7      3049502      IA              Story County
# ...        ...     ...                       ...
# 67278  3057399      TX            El Paso County
# 67279  3057398      TX            El Paso County
# 67309  3052682      NY               Erie County
# 67913  3003325      AK  Northwest Arctic Borough
# 67914  3001855      AK  Northwest Arctic Borough
#
#                               p_name  p_year  p_tnum   p_cap  retrofit  \
# 3            30 MW Iowa DG Portfolio  2017.0      10  30.000         0
# 4            30 MW Iowa DG Portfolio  2017.0      10  30.000         0
# 5            30 MW Iowa DG Portfolio  2017.0      10  30.000         0
# 6            30 MW Iowa DG Portfolio  2017.0      10  30.000         0
# 7            30 MW Iowa DG Portfolio  2017.0      10  30.000         0
# ...                              ...     ...     ...     ...       ...
# 67278         unknown El Paso County  2015.0       2   3.400         0
# 67279         unknown El Paso County  2015.0       2   3.400         0
# 67309            unknown Erie County  2016.0       2   0.200         0
# 67913  unknown Kotzebue Wind Project  2003.0      15   0.975         0
# 67914  unknown Kotzebue Wind Project  2003.0      15   0.975         0
#
#             xlong       ylat                  t_manu     t_model   t_cap  \
# 3      -93.430367  42.028233                  Nordex  AW125/3000  3000.0
# 4      -93.700424  41.977608                  Nordex  AW125/3000  3000.0
# 5      -93.632835  41.882477                  Nordex  AW125/3000  3000.0
# 6      -93.515892  42.016373                  Nordex  AW125/3000  3000.0
# 7      -93.518082  42.013630                  Nordex  AW125/3000  3000.0
# ...           ...        ...                     ...         ...     ...
# 67278 -106.405434  31.788124                 GE Wind   GE1.7-100  1700.0
# 67279 -106.405670  31.788097                 GE Wind   GE1.7-100  1700.0
# 67309  -78.931122  42.977005  Northern Power Systems     NPS-100   100.0
# 67913 -162.557327  66.834328                Seaforth    AOC15/65    65.0
# 67914 -162.551575  66.837898                Seaforth    AOC15/65    65.0
#
#        t_hh   t_rd     t_rsa  t_ttlh  t_conf_atr    size
# 3      87.5  125.0  12271.85   150.0         3.0   large
# 4      87.5  125.0  12271.85   150.0         3.0   large
# 5      87.5  125.0  12271.85   150.0         3.0   large
# 6      87.5  125.0  12271.85   150.0         3.0   large
# 7      87.5  125.0  12271.85   150.0         3.0   large
# ...     ...    ...       ...     ...         ...     ...
# 67278  80.0  100.0   7853.98   130.1         3.0  medium
# 67279  80.0  100.0   7853.98   130.1         3.0  medium
# 67309  37.0   21.0    346.36    47.5         3.0   small
# 67913  30.5   15.0    176.71    38.0         1.0   small
# 67914  30.5   15.0    176.71    38.0         1.0   small
#
# [64478 rows x 19 columns]

# %%
turbine_sizes.to_csv('../cleaned_datasets/turbine_sizes.csv')
